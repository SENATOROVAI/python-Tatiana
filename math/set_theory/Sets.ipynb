# %% [markdown]
# ![ksnip_20231113-01.png](attachment:ksnip_20231113-01.png)

# %% [markdown]
# ![ksnip_20231113-02.png](attachment:ksnip_20231113-02.png)

# %% [markdown]
# ![ksnip_20231113-03.png](attachment:ksnip_20231113-03.png)

# %% [markdown]
# ![ksnip_20231113-04.png](attachment:ksnip_20231113-04.png)

# %% [markdown]
# ![ksnip_20231113-05.png](attachment:ksnip_20231113-05.png)

# %% [markdown]
# ![ksnip_20231113-06.png](attachment:ksnip_20231113-06.png)

# %% [markdown]
# ![ksnip_20231113-07.png](attachment:ksnip_20231113-07.png)

# %% [markdown]
# ![ksnip_20231113-08.png](attachment:ksnip_20231113-08.png)
