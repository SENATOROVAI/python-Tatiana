# %% [markdown]
# # Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Plotting vectors

# %% [markdown]
# Axes are defined for arrays with more than one dimension. A 2-dimensional array has two corresponding axes: the first running vertically downwards across rows (axis 0), and the second running horizontally across columns (axis 1). Many operation can take place along one of these axes.

# %%
# # Display row vector ([[]])
v_r = np.array([[2, -1]]) # tail [2,-1]
plt.plot([0,v_r[0][0]], [0, v_r[0][1]]) # v[0]- first row, v[0][0] - first row, first column(equals 2),
# v[0][1]]- first row, second column(equals -1)
plt.axis([-2, 2, -2, 2])# OX(axis=1) (-3, 3), OX(axis=0):(-3, 3)
print(v_r , v_r.shape)
# Out:
# [[ 2 -1]] (1, 2)

# %%
# Display  no orientation vector vector ([])
v = np.array([2, -1]) # вектор строка! указываем координату конца вектора (tail) [2,-1]
plt.plot([0,v[0]], [0, v[1]]) #отображаем на гарфике: (axis=1(x):[head, tail], axis=0(y):[head, tail])
print(v, v.shape)
# Out:
# [ 2 -1] (2,)

# %% [markdown]
# # Types of vectors, transposing

# %%
# List
v1 = [2, 5, 4, 7] 
# Vectors 
v2 = np.array(v1) # no orientation vector. Occures when we feed the list to np.array
v3 = np.array([[2], [7], [5], [6]])# vector column ([[]])
v4 = np.array([[2, 5, 4, 7]]) # vector row

print('list:', v1)
print('no orientation vector shape:',  v2.shape, '\n',v2, '\n')
print('vector column shape:', v3.shape,'\n', v3, '\n')
print('vector row shape:', v4.shape,'\n', v4,)
# Out:
# list: [2, 5, 4, 7]
# no orientation vector shape: (4,)
#  [2 5 4 7]
#
# vector column shape: (4, 1)
#  [[2]
#  [7]
#  [5]
#  [6]]
#
# vector row shape: (1, 4)
#  [[2 5 4 7]]

# %%
v = np.zeros(5, dtype='int')# creating zero vector
v
# Out:
# array([0, 0, 0, 0, 0])

# %%
# Transposing different types of vectors
v = np.array([25, 5, 78])# no orientation vector
v_t = v.T
v1 = np.array([[25, 5, 78]]) # creating a row vector  in three-dimensional space
v2 = v1.T # transponed vector row to vector-column
print('Row vector :', v1,'\n','Transposed row vector into column vector:','\n', v2)

print('Vector shapes row vector,column vector: ', v1.shape, v2.shape)
print('No orientation vector , no orientation vector shape: ', v , v.shape)
print('Transposed no orientation vector, transposed no orientation vector shape:',v_t, v_t.shape)
# Out:
# Row vector : [[25  5 78]]
#  Transposed row vector into column vector:
#  [[25]
#  [ 5]
#  [78]]
# Vector shapes row vector,column vector:  (1, 3) (3, 1)
# No orientation vector , no orientation vector shape:  [25  5 78] (3,)
# Transposed no orientation vector, transposed no orientation vector shape: [25  5 78] (3,)

# %% [markdown]
# # Multiplication of vectors

# %%
# Compound vector multiplication. Result - vector. 
v1 = np.array( [ 2 , 5 , 4 , 7 ] )
v2 = np.array( [ 4 , 1 , 0 , 2 ] )
# v1 = np.array( [[ 1 , 2]]).T # test for different directions
# v2 = np.array( [ 3 , 4 ] ) #
v3 = 4*v1 - 2*v2
v3
# Out:
# array([[-2, -4],
#        [ 2,  0]])

# %%
# создадим 2 вектра разной направленности
a = np.array([[1, 2, 3]]) # row v.
b = np.array([[-1],[2], [-3]]) # column v.
print(a.shape, b.shape)
b
# Out:
# (1, 3) (3, 1)
# array([[-1],
#        [ 2],
#        [-3]])

# %%
# Sqaclar vector product (Умножение вектора на скаляр)
c = 2*a #  [1, 2, 3] * 2
c
# Out:
# array([[2, 4, 6]])

# %%
# vector + vector
a = np.array([[1, 2, 3]]) # row v.
b = np.array([[-1],[2], [-3]]) # column v.
sum1 = a+b.T # sum of 2 row vectors => vector
sum2 = a+b #  row vector + column v.=> matrix
print(sum1, '\n')
print(sum2)
# Out:
# [[0 4 0]]
#
# [[ 0  1  2]
#  [ 3  4  5]
#  [-2 -1  0]]

# %%
# len displays the number of rows in a vector
print(len(a), a.shape,  a)
print(len(b), b.shape, '\n',  b)
# Out:
# 1 (1, 3) [[1 2 3]]
# 3 (3, 1)
#  [[-1]
#  [ 2]
#  [-3]]

# %% [markdown]
# # Broacasting
# np.dot, np.outer, np.linalg.norm

# %% [markdown]
# Транслирование векторов (broacasting) -  операция многократного повторения между оним вектором и каждым элементов другого вектора. Процедура позволяющая путем сжатия векторв разжать их и получить матрицу. Л

# %%
# norm of the vector = magnitude
v_mag = np.linalg.norm(a)# норма вектора=модуль вектотра=евклидово расстояние
v_mag
# Out:
# 3.7416573867739413

# %%
# Scalar = inner product of two vectors. Result - scalar
# операция "внешнее произведение" = создание ма=трицы из векторов 
a = np.array([[1, 2, 3]]) # row v
b = np.array([[-1],[2], [-3]]) # column v.
print(np.dot(a,b)) # row * column : (1, 3)*(3,1)= 1*(-1)+2*2+3*(-3)= -1+4-9=-6
#print(np.outer(a, b)) # операция "внешнее произведение" = создание матрицы из векторов
# Out:
# [[-6]]

# %%
help(np.dot)

# %%
# broacasting = транслирование
a = np.array([[1, 2, 3]]) # row v.
b = np.array([[-1],[2], [-3]]) # column v.
print(np.dot(b, a)) # column * row
#np.outer(b, a) # операция "внешнее произведение" = создание матрицы из векторов
# Out:
# [[-1 -2 -3]
#  [ 2  4  6]
#  [-3 -6 -9]]

# %%
a.shape, b.shape
# Out:
# ((1, 3), (3, 1))

# %%
import numpy as np
n = np.array([1, -2])

dir(n)
# Out:
# ['T',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_finalize__',
#  '__array_function__',
#  '__array_interface__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_struct__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__class_getitem__',
#  '__complex__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__divmod__',
#  '__dlpack__',
#  '__dlpack_device__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__ilshift__',
#  '__imatmul__',
#  '__imod__',
#  '__imul__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__irshift__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
# ...

# %% [markdown]
# # Gaussian distribution

# %% [markdown]
# Норма́льное распределе́ние (распределение Гаусса), одно из важнейших распределений вероятностей. Термин «нормальное распределение», принадлежащий К. Пирсону (более старые названия – закон Гаусса, распределение Гаусса – Лапласа), применяют как по отношению к распределениям вероятностей случайных величин, так и по отношению к совместным распределениям вероятностей нескольких случайных величин (т. е. к распределениям конечномерных случайных векторов), а также случайных элементов и случайных процессов. Общее определение нормального распределения сводится к одномерному случаю.

# %% [markdown]
# In statistics, a normal distribution or Gaussian distribution is a type of continuous probability distribution for a real-valued random variable.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
v = np.array([1, 2])
plt.plot([0,v[0]], [0, v[1]])

for i in range(10):
    scalar = np.random.randn()
    sv = scalar *  v
    plt.plot([0, sv[0]], [0, sv[1]])
    # print(scalar)
plt.grid()

# plt.axis([-4, 4, -4, 4])

# %%
v = np.array([4 , 3, 8])
w = np.array([[5], [2], [6]])
plt.plot

# %%
# Scalar product = inner product of 2 vectors. Result - scalar
v = np.array([4 , 3, 8])
w = np.array([5, 7, 8])

dp = np.dot(v,w)
print((5*4 + 7*3 + 8*8), '=', dp)
# Out:
# 105 = 105

# %% [markdown]
# # Scalar product = inner product

# %%
# Scalar product = inner product of 2 vectors. Result - scalar
v  = np.arange(5) # генерация векторов
v1 = np.zeros(5)
v2 = np.ones(5)
v_scal_multy = np.dot(v,v2)# 
v_scal_multy
# Out:
# 10.0

# %%
# Searching for the max digit in a vector
w = np.array([5, 80, 1, 2])
np.linalg.norm(w) # норма вектора = длина (madnitude of a vector)
np.max(w) # максимальное число в векторе
# Out:
# 80

# %%
# extracting only even digits from the vector
v = np.arange(1,5) # creating  row vector
even_el = v[v%2==0]
print(v,'=> even digits:', even_el)
# Out:
# [1 2 3 4] => even digits: [2 4]

# %%
# векторное произведение. Должны совпадать размерности!
a = np.array([1, 0,  0])
b = np.array([0, 1,  0])
cross_product = np.cross(a,b)
cross_product
# Out:
# array([0, 0, 1])

# %%
# Broadcasting: result  - matrix. Sizes differ
import numpy as np 
a_row = np.array([[1, 2, 3]])# 
a_col = np.array([[1, 2]]).T#
broadcasting = a_row + a_col
broadcasting
# Out:
# array([[2, 3, 4],
#        [3, 4, 5]])

# %%
# Scalar vector product = inner product
a = np.array([1, 2, 3])
b = np.array([1, 2, 3])
c = np.array([1, 2, 3])
inner_product = np.dot(a, b)
inner_product # the result is scalar
# Out:
# 14

# %%
#Prove of the  Distributive property of scalar vactor product
np.dot(a, b+c) == np.dot(a, b) + np.dot(a, c)
# Out:
# True

# %% [markdown]
# # Hadamard multiplication

# %%
# Siimply multiplication of vectors. Shapes should be equal.
# Result- new vector of equal shape

v =  np.array([1, 2, 3])
w = np.array([5, 4, 3])
v + w
# Out:
# array([6, 6, 6])

# %% [markdown]
# # Vector problems from Senatorov

# %% [markdown]
# ## Problem 1:
# create a vector - v, and count its norm

# %%
v = np.array([2, 4, 3]) # no orinted vector result -  14.5
#v =np.array([[2,4,3]]) # [2.  8.  4.5]
#v = np.array([[2], [4], [3]]) # [14.5]

v_norm =  0

for i in v: 
    v_norm += i**2
print(v_norm**0.5)
# Out:
# 5.385164807134504

# %%
import numpy as np
v : list = np.array([2, 4, 3]) # no orinted vector result -  5.385164807134504
np.linalg.norm(v) # norm vector

def norm_of_vector(vector: list) -> bool:
    return np.sqrt(np.sum(vector**2)) == np.linalg.norm(vector)
#help(np)
norm_of_vector(v)
# Out:
# True

# %%
np.linalg.norm(v, ord=2) # ord=2 -  euclidian distance
np.linalg.norm(v, ord = 1) # ord=1 - manhettan
# Out:
# 5.385164807134504

# %% [markdown]
# ## Problem 2:
# Создайте функцию Python, которая на входе будет принимать вектор, а на
# выходе – выдавать единичный вектор в том же направлении.

# %% [markdown]
# Для создания нового вектора с тем же направлением, но длиной равной 1, нужно разделить исходный вектор на его длину (модуль):
# 1. найти дину исходного вектора
# 2. разделить исходный вектор(покоординатно) на его модуль

# %%
v : list = np.array([-2, 4, -3, 4, 5, 7]) # no orinted vector

def one_vector(vector:list) -> np.ndarray:
    magnitude = np.sqrt(np.sum(vector**2))# count the magnitude of the input vector
    vect = [coord/magnitude for coord in vector]#creare a vector by deviding each coordinate of the input vector to its magnitude 
    if np.linalg.norm(vect) == 1.0:# verify if the norm of the ouput vector equals 1.0
        return vect

one_vector(v)
# Out:
# [-0.18333969940564226,
#  0.36667939881128453,
#  -0.2750095491084634,
#  0.36667939881128453,
#  0.4583492485141057,
#  0.641688947919748]

# %% [markdown]
# #

# %%
A = np.array([[1,2],[3,4]])
Ainv  = np.linalg.inv(A)
# print(A, Ainv)
# Ainv.dot(A)
A.dot(Ainv)

# Ainv
# Out:
# array([[1.00000000e+00, 1.11022302e-16],
#        [0.00000000e+00, 1.00000000e+00]])

# %%
a = np.array([1, 2, 3])
b = np.array([4, 4, 4])
print(f'Поэлементное умножение {a*b} \n Скалярное(inner) произведение:{a.dot(b)} = {np.inner(a,b)} \n outer product:\n {np.outer(a,b)}')
# Out:
# Поэлементное умножение [ 4  8 12]
#  Скалярное(inner) произведение:24 = 24
#  outer product:
#  [[ 4  4  4]
#  [ 8  8  8]
#  [12 12 12]]

# %% [markdown]
# # Architecture

# %% [markdown]
# __init.py__ - это автозагрузчик файлов. Он вызывается автоматически когда в модуле присутствует import. В init.py сигнализирует для интерпретатора что директория является пакетом.Пакет - это совокупность модулей.То nupy  это пакет(совоупнгсть модулей)
# init - файл помойка где содержаться только импорты и  не тольк

# %% [markdown]
# from ._globals import -  . - означает поиск в текущей директории, т.е на уровне расположения файла(модуля), а .. - это поднятся на директорию выше.

# %%
dir(np)
# Out:
# ['ALLOW_THREADS',
#  'AxisError',
#  'BUFSIZE',
#  'CLIP',
#  'ComplexWarning',
#  'DataSource',
#  'ERR_CALL',
#  'ERR_DEFAULT',
#  'ERR_IGNORE',
#  'ERR_LOG',
#  'ERR_PRINT',
#  'ERR_RAISE',
#  'ERR_WARN',
#  'FLOATING_POINT_SUPPORT',
#  'FPE_DIVIDEBYZERO',
#  'FPE_INVALID',
#  'FPE_OVERFLOW',
#  'FPE_UNDERFLOW',
#  'False_',
#  'Inf',
#  'Infinity',
#  'MAXDIMS',
#  'MAY_SHARE_BOUNDS',
#  'MAY_SHARE_EXACT',
#  'ModuleDeprecationWarning',
#  'NAN',
#  'NINF',
#  'NZERO',
#  'NaN',
#  'PINF',
#  'PZERO',
#  'RAISE',
#  'RankWarning',
#  'SHIFT_DIVIDEBYZERO',
#  'SHIFT_INVALID',
#  'SHIFT_OVERFLOW',
#  'SHIFT_UNDERFLOW',
#  'ScalarType',
#  'Tester',
#  'TooHardError',
#  'True_',
#  'UFUNC_BUFSIZE_DEFAULT',
#  'UFUNC_PYVALS_NAME',
#  'VisibleDeprecationWarning',
#  'WRAP',
#  '_CopyMode',
#  '_NoValue',
#  '_UFUNC_API',
#  '__NUMPY_SETUP__',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__config__',
#  '__deprecated_attrs__',
#  '__dir__',
#  '__doc__',
# ...

# %%
np.sum()

# %% [markdown]
# from . import fromnumeric - импорт всего файла и з текущей директории
# from .файл import * - импорт всех пространств имен(функций и классов)

# %%
#import numpy.core.fromnumeric
from numpy.core import fromnumeric
dir(fromnumeric)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_all_dispatcher',
#  '_amax_dispatcher',
#  '_amin_dispatcher',
#  '_any_dispatcher',
#  '_argmax_dispatcher',
#  '_argmin_dispatcher',
#  '_argpartition_dispatcher',
#  '_argsort_dispatcher',
#  '_around_dispatcher',
#  '_choose_dispatcher',
#  '_clip_dispatcher',
#  '_compress_dispatcher',
#  '_cumprod_dispatcher',
#  '_cumsum_dispatcher',
#  '_diagonal_dispatcher',
#  '_dt_',
#  '_gentype',
#  '_mean_dispatcher',
#  '_methods',
#  '_ndim_dispatcher',
#  '_nonzero_dispatcher',
#  '_partition_dispatcher',
#  '_prod_dispatcher',
#  '_ptp_dispatcher',
#  '_put_dispatcher',
#  '_ravel_dispatcher',
#  '_repeat_dispatcher',
#  '_reshape_dispatcher',
#  '_resize_dispatcher',
#  '_searchsorted_dispatcher',
#  '_shape_dispatcher',
#  '_size_dispatcher',
#  '_sort_dispatcher',
#  '_squeeze_dispatcher',
#  '_std_dispatcher',
#  '_sum_',
# ...

# %%
fromnumeric._dt_('u')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 fromnumeric._dt_('u')
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/core/numerictypes.py:500, in sctype2char(sctype)
#     498 sctype = obj2sctype(sctype)
#     499 if sctype is None:
# --> 500     raise ValueError("unrecognized type")
#     501 if sctype not in _concrete_types:
#     502     # for compatibility
#     503     raise KeyError(sctype)
#
# ValueError: unrecognized type

# %%
fromnumeric._sum_((3,2))
# Out:
# 5

# %%
Равность векторов:
1) коллиниарны, сонаправлены
2) равна длина
все нулевые векторы равны друг другу

# %% [markdown]
# Адамарово умножение

# %%
v = np.array([1,2])
w = np.array([3,4])
norm_v = np.linalg.norm(v)
norm_w = np.linalg.norm(w)
np.dot(v, w) == np.inner(v, w)
cos = np.dot(v, w)/(norm_v*norm_w) # расчет косинуча из скалярное произведения
round(cos,2)
# np.arccos(round(cos,2))
# Out:
# 0.20033484232311968

# %%
# dir(np)
#help(np.linalg.det)
 
norm_v = np.array([[-126,2], [3,4]], dtype="int8") # int8 => -128 to 127
norm_v.ndim

# detvw = np.linalg.det([v, w])
detvw = np.linalg.det(norm_v)
detvw, norm_v
# Out:
# (-509.9999999999999,)

# %%
norm_v.dtype
# Out:
# dtype('int64')

# %%
norm_v.nbytes
# Out:
# 4

# %%
dir(norm_v)
# Out:
# ['T',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_finalize__',
#  '__array_function__',
#  '__array_interface__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_struct__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__class_getitem__',
#  '__complex__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__divmod__',
#  '__dlpack__',
#  '__dlpack_device__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__ilshift__',
#  '__imatmul__',
#  '__imod__',
#  '__imul__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__irshift__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
# ...

# %%
# norm_v.nbytes # атрибут это свойство класса

class ndarra:
    nbytes = 33 # свойство класса / атрибут / поле, отображается во всех объекта

    def nbytes1(self):
        return self.nbytes

    def nbytes2(self, byte):
        return byte

norv_v = ndarra()

# ndarra.nbytes # от класса
# norv_v.nbytes # от объекта
norv_v.nbytes1()
norv_v.nbytes2(33)
# Out:
# 33

# %%
a = np.array([2,7,3])
b = np.array([5,9,3])
c = np.array([7,4,5])
#(axb)*c 
# matrix = np.matrix([a,b,c])
# round(np.linalg.det(matrix), 0) # смешанное произведение векторов ищется по определителю матрицы

# %%
np.cross(a, b) # векторное произведение векторов, получаем вектор kj
#np.dot(np.cross(a, b), c) # получили объем параллелепипеда построенного на наших векторах, вектора не компланарны потому что результат != 0
# Out:
# array([ -6,   9, -17])

# %%
v= np.array([1,2])
w = np.array([3,4])
print(v*w)# адамарово произведение
# внешнее произведение
np.linalg.norm(v,w)
np.cross(v, w)
np.dot(np.cross(v,w),c)
# Out:
# [3 8]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 5
#       3 print(v*w)# адамарово произведение
#       4 # внешнее произведение
# ----> 5 np.linalg.norm(v,w)
#       6 np.cross(v, w)
#       7 np.dot(np.cross(v,w),c)
#
# File <__array_function__ internals>:200, in norm(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/numpy/linalg/linalg.py:2503, in norm(x, ord, axis, keepdims)
#    2499 if axis is None:
#    2500     ndim = x.ndim
#    2501     if ((ord is None) or
#    2502         (ord in ('f', 'fro') and ndim == 2) or
# -> 2503         (ord == 2 and ndim == 1)):
#    2505         x = x.ravel(order='K')
#    2506         if isComplexType(x.dtype.type):
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %% [markdown]
# # Snaps for linear algebra

# %% [markdown]
# ![math_311023_01.png](attachment:math_311023_01.png)

# %% [markdown]
# ![math_311023_02.png](attachment:math_311023_02.png)

# %% [markdown]
# ![math_311023_03.png](attachment:math_311023_03.png)

# %% [markdown]
# ![math_311023_04.png](attachment:math_311023_04.png)

# %% [markdown]
# ![math_311023_04_2.png](attachment:math_311023_04_2.png)

# %% [markdown]
# ![math_311023_05.png](attachment:math_311023_05.png)

# %% [markdown]
# ![math_311023_06.png](attachment:math_311023_06.png)

# %% [markdown]
# ![math_311023_07.png](attachment:math_311023_07.png)

# %% [markdown]
# ![2023-10-31-182726_1366x768_scrot.png](attachment:2023-10-31-182726_1366x768_scrot.png)

# %% [markdown]
# ![math_311023_векторолизв.png](attachment:math_311023_векторолизв.png)

# %%
# Out:
# [2]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 10
#       8 print(list2)
#       9 del list2
# ---> 10 id(list2)
#
# NameError: name 'list2' is not defined

# %%
# Out:
# 25
# 25

# %% [markdown]
# ![ksnip_20231111-081231.png](attachment:ksnip_20231111-081231.png)

# %% [markdown]
# ![ksnip_20231111-081231.png](attachment:ksnip_20231111-081231.png)

# %%
# Out:
#   4           0 RESUME                   0
#
#   5           2 LOAD_FAST                0 (x)
#               4 LOAD_GLOBAL              0 (i)
#              16 BINARY_OP                8 (**)
#              20 RETURN_VALUE
# 25
# 25

# %%
# Out:
#   2           0 RESUME                   0
#
#   3           2 LOAD_FAST                0 (x)
#               4 LOAD_CONST               1 (1)
#               6 BINARY_OP                0 (+)
#              10 RETURN_VALUE
