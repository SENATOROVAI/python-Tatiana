# %%
"Module on work with files."

# %%
import datetime
import math

# %% [markdown]
# # ввод и вывод данных

# %% [markdown]
# В Python есть встроенная функция
# input (), которая делает именно это. Синтаксис функции input ():
# input (prompt}
# где prompt — это строка, которую мы хотим отобразить на экране.

# %%
#
print(f"The value of pi is approximately {math.pi:.3f}")
# Out:
# The value of pi is approximately 3.142

# %%
# без спецификатора формата
table = {"Sjoerd": 4127, "Jack": 4098, "Dcab": 7678}
for name, phone in table.items():
    print(f"{name} ==> {phone}")
# Out:
# Sjoerd ==> 4127
# Jack ==> 4098
# Dcab ==> 7678

# %%
# целое число после двоеточия задает минимальную ширину вывода
table = {"Sjoerd": 4127, "Jack": 4098, "Dcab": 7678}
for name, phone in table.items():
    print(f"{name:10} ==> {phone:10}")
# Out:
# Sjoerd     ==>       4127
# Jack       ==>       4098
# Dcab       ==>       7678

# %% [markdown]
# Для преобразования значения перед выводом можно использовать и другие моди­
# фикаторы. Так, например, !а применит к значению функцию ascii о, is — функцию

# %%
animals = "eels"
print(f"Му hovercraft is full of {animals}.")
# применим !r
print(f"My hovercraft is full of {animals!r}.")
# Out:
# Му hovercraft is full of eels.
# My hovercraft is full of 'eels'.

# %% [markdown]
# [руководстве по спе­
# цификации формата Mini Language](https://docs.python.Org/3.7/library/string.html#formatspec)

# %%
print("{0] and {1}".format("spam", "eggs"))
print("{1} and {0}".format("spam", "eggs"))

# %%
print(
    "This [food] is {adjective}.".format(food="spam", adjective="absolutely horrible")
)

# %%
print(f"The story of {0}, {1}, and {other}".format("Bill", "Manfred", other="Georg"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-f7947c3bbb14> in <cell line: 1>()
# ----> 1 print(f'The story of {0}, {1}, and {other}'.format('Bill','Manfred', other ='Georg'))
#
# NameError: name 'other' is not defined

# %%
# Вы, наверное, заметили здесь спецификатор формата d после двоеточия. Он ис­
# пользуется для перевода данных в нужный формат перед выводом.
table = {"Sjoerd": 4127, "Jack": 4098, "Dcab": 8637678}
print("Jack: {0[Jack]:d}; Sjoerd: {0[Sjoerd]:d}; Dcab: {0[Dcab]:d}".format(table))
# Out:
# Jack: 4098; Sjoerd: 4127; Dcab: 8637678

# %%
table = {"Sjoerd": 4127, "Jack": 4098, "Dcab": 8637678}
print("Jack: {Jack:d}; Sjoerd: {Sjoerd:d}; Dcab: {Dcab:d}".format(**table))
# Out:
# Jack: 4098; Sjoerd: 4127; Dcab: 8637678

# %% [markdown]
# [форматирование](https://docs.python.Org/3.7/Iibrary/string.html#formatspec)

# %%
# выводятся выровненные столбцы

for x in range(1, 11):
    print("{:2d} {:3d} {:4d}".format(x, x * x, x * x * x))
# Out:
#  1   1    1
#  2   4    8
#  3   9   27
#  4  16   64
#  5  25  125
#  6  36  216
#  7  49  343
#  8  64  512
#  9  81  729
# 10 100 1000

# %%
# Форматирование строк вручную

for x in range(1, 11):
    print(repr(x).rjust(2), repr(x * x).rjust(3), repr(x * x * x).rjust(4))
# Out:
#  1   1    1
#  2   4    8
#  3   9   27
#  4  16   64
#  5  25  125
#  6  36  216
#  7  49  343
#  8  64  512
#  9  81  729
# 10 100 1000

# %% [markdown]
# между столбцами появляется дополнительный пробел,
# т. к. функция print {) всегда добавляет пробел между аргументами.
# Строковый метод rjusto выравнивает строку по правому краю в поле заданной
# ширины, заполняя строку пробелами слева. Похожим образом работают методы
# 1 just о и center о. Эти методы ничего не выводят на экран, а просто возвращают
# новую строку.
# Существует еще один метод zfilio, который дополняет строку нулями. В этом
# методе можно использовать плюсы и минусы.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ♦ Функция str () используется для создания вывода для конечного пользователя, а
# герг () в основном используется для целей отладки и разработки. Функция герг ()
# дает однозначность, a str () — удобочитаемость. Например, если мы подозрева­
# ем, что у числа с плавающей точкой есть небольшая ошибка округления, герг о
# покажет нам ее, a str () — нет.
# ♦ Функция герг о возвращает «формальное» строковое представление объекта
# (представление, которое содержит всю информацию об объекте), astro исполь-212
# |
# Глава 9
# зуется для вывода «неформального» строкового представления объекта (более
# понятное с точки зрения пользователя)

# %%
today = datetime.datetime.now()
# удобочитаемый формат для объекта даты и времени
print(str(today))
# официальный формат для объекта даты и времени
print(repr(today))
# Out:
# 2024-07-27 19:46:10.901344
# datetime.datetime(2024, 7, 27, 19, 46, 10, 901344)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Чтение и запись файлов

# %% [markdown]
# Обычно файлы открываются в текстовом режиме, что означает, что вы читаете из
# файла и записываете в файл строки в определенной кодировке.
# Метод open о возвращает файловый объект и чаще всего используется с двумя
# аргументами:
# f = open (имя_файла, режим')
# Первый аргумент— это строка, содержащая имя файла. Второй аргумент— это
# тоже строка-режим использования
# файла.
#
# Режим может состоять из:
# * ♦ 'г' —  только для чтения; СТОИТ ПО УМОЛЧАНИЮ
# * ♦'w' — только для записи (если файл с таким же именем уже
# существует, он будет перезаписан);
# * ♦ ' а' —  для добавления; любые данные, записываемые в файл,
# добавляются в его конец;
# * ♦ ' г+ ’ — файл открывается как для чтения, так и для записи.

# %% [markdown]
# При работе с файловыми объектами рекомендуется использовать ключевое слово
# with. Преимущество его использования заключается в том, что файл правильно
# закрывается после завершения работы, даже если в какой-то момент возникнет ис­
# ключение.
#
# Если вы не используете ключевое слово with, то в конце нужно вызвать метод
# f.close(), чтобы закрыть файл и высвободить все используемые им системные
# ресурсы.

# %%
with open('workfile') as f:
read_data = f.read()
f.close()

# %%
Если достигнут конец файла, f.read() вернет пустую строку ('').
f.read()
# если файл состоит из одной строки, то ""

# %%
# Метод f. readline () читает одну строку из файла. При каждом вызове метода чита­
# ется следующая строка

# %%
# Для последовательного чтения строк из файла
for line in f:
    print(line, end="")

# %% [markdown]
# извлечь все строки файла в список, вы можете использовать функ­
# цию list(f) ИЛИ метод f .readlines()

# %% [markdown]
# f. write (string) -  записывает содержимое строки в файл, возвращая количество
# записанных символов.

# %% [markdown]
# Другие типы объектов перед записью необходимо преобразовать — либо в строку
# (в текстовом режиме), либо в байтовый объект (в бинарным режиме)

# %%
value = ("the answer", 42)
s = str(value)
# преобразование кортежа в строку
f.write(s)

# %% [markdown]
# # Создание файла и запись в него

# %%
# строковая переменная с произвольным текстом
story = ' ''
Lets write a small story.
There was a curious student. He wanted to learn Python.
His age was... Well, how does it matter. One can be student at any age.
Lets say, he was a good student and within a short time, learnt all about
programming and python. He combined that with his business acumen, and
became a good data scientist.'1'
# создание нового текстового файла
f = openCsmall_story.txt", "w")

# Выполнив последнюю строку кода, мы создали новый файл с именем small_
# story.txt.

# запись текстовой переменной story в файл f
f.write(story)
# получаем количество символов, записанных в файле
f.close()

# %% [markdown]
# # Открытие файла и чтение его содержимог

# %%
# по умолчанию файл открыт только для чтения
f = openCsmall("story.txt", "r")
# простой вызов переменной не выводит на экран текст из файла,
# а только информацию о файловом объекте
f

# %%
f.read()

# %% [markdown]
# # Построчное чтение

# %%
f = openCsmall_story.txt")
f .readline ()

# %% [markdown]
# 9.5.2. Правда или ложь
# 1. Строковое приглашение в функции
# input
# является обязательным.
# 2. Функция input () всегда возвращает строку.
# 3. Функция
# 4. Метод
# input о
# format ()
# принимает в качестве входных данных только строки.
# использует фигурные скобки {} как заполнители.
# 5. Если в методе format!) используются именованные аргументы, на их значения
# можно ссылаться, используя имя аргумента.
# 6. Порядок объектов в форматируемой строке изменить нельзя.
# 7. Функция
# str ()
# 8. Аргументы
# 'г'
# используется для строк, а
# и
# 'г+'
# функции
# open!)
# герг()
# —для чисел.
# выполняют одну и ту же функцию.
# 9. В Python мы можем открывать только существующие файлы, а создавать новые
# файлы нельзя.
# 10. В Python можно читать только текстовые файлы

# %% [markdown]
# Давайте по порядку ответим на ваши вопросы.
#
# ### 1. Что делает функция input()?
# Функция input() в Python используется для считывания строки, введенной пользователем с клавиатуры. Она останавливает выполнение программы и ждет, пока пользователь введет данные и нажмет Enter. В Python 3.x input() всегда возвращает строку. В Python 2.x для получения строки используется raw_input(), а input() пытается выполнить введенное выражение.
#
# ### 2. Как отформатировать строки с помощью метода format()?
# Метод format() позволяет вставлять значения в строки, используя фигурные скобки {} как плейсхолдеры. Например:
# name = "Alice"
# age = 30
# formatted_string = "Name: {}, Age: {}".format(name, age)
# print(formatted_string)  # Вывод: Name: Alice, Age: 30
#
# Можно также использовать именованные параметры:
# formatted_string = "Name: {name}, Age: {age}".format(name=name, age=age)
#
#
# ### 3. Как ограничить размер считываемого файла на Python? Почему это важно?
# Чтобы ограничить размер считываемого файла, можно использовать аргументы в методах чтения, например, при чтении с помощью read(size) можно указать количество байт для чтения. Это важно для управления памятью и предотвращения загрузки слишком больших файлов в оперативную память, что может привести к замедлению работы программы или ее падению.
#
# ### 4. Зачем нам нужно открывать сторонние файлы в Python?
# Открытие сторонних файлов позволяет программе взаимодействовать с внешними данными, такими как текстовые документы, изображения, базы данных и т.д. Это дает возможность считывать данные для обработки или записывать результаты работы программы в файл для дальнейшего использования.
#
# ### 5. Какое будет имя у этого файла на жестком диске?
# В приведенном коде файл будет называться textfile.txt. Он создается в текущем рабочем каталоге программы.
#
# ### 6. Сравните работу методов write() и writelines().
# - **write()**: записывает одну строку в файл. Если вы хотите записать несколько строк, нужно вызывать его несколько раз.
# - **writelines()**: принимает список строк и записывает их все сразу в файл. Однако он не добавляет символы новой строки между строками, поэтому их нужно добавлять вручную.
#
# Пример:
# with open('example.txt', 'w') as f:
#     f.write("Hello\n")
#     f.writelines(["Line 1\n", "Line 2\n"])
#
#
# ### 7. Сравните методы read(), readline() и readlines().
# - **read()**: считывает весь файл целиком и возвращает его содержимое как одну строку.
# - **readline()**: считывает одну строку за раз из файла. Каждый вызов возвращает следующую строку.
# - **readlines()**: считывает все строки файла и возвращает их в виде списка строк.
#
# ### 8. Какие режимы можно использовать с функцией open() при открытии файла?
# Некоторые основные режимы:
# - 'r': чтение (по умолчанию).
# - 'w': запись (создает новый файл или перезаписывает существующий).
# - 'a': добавление (добавляет данные в конец файла).
# - 'b': бинарный режим (например, 'rb' для чтения бинарных файлов).
# - 't': текстовый режим (по умолчанию).
#
# Пример открытия файла для записи:
# with open('example.txt', 'w') as f:
#     f.write("Hello")
#
#
# ### 9. Объясните работу методов str() и repr().
# - **str()**: возвращает строковое представление объекта, которое удобно для человека (читаемое).
# - **repr()**: возвращает строковое представление объекта, которое удобно для разработчика и может быть использовано для восстановления объекта (если это возможно).
#
# Пример:
# s = "Hello"
# print(str(s))   # Вывод: Hello
# print(repr(s))  # Вывод: 'Hello'
#
#
# ### 10. В чем разница между функциями read() и readline()?
# - **read()** считывает весь файл целиком и возвращает его содержимое как одну строку.
# - **readline()** считывает одну строку за раз из файла. Каждый вызов возвращает следующую строку.
#
# Если у вас есть дополнительные вопросы или требуется более подробное объяснение, дайте знать!

# %% [markdown]
# 1. **Строковое приглашение в функции input является обязательным.**
#    - **Ложь.** Строковое приглашение (аргумент) в функции input() является необязательным. Если его не указать, функция просто будет ждать ввода от пользователя.
#
# 2. **Функция input() всегда возвращает строку.**
#    - **Правда.** В Python 3.x функция input() всегда возвращает введенные данные в виде строки.
#
# 3. **Метод format() принимает в качестве входных данных только строки.**
#    - **Ложь.** Метод format() может принимать любые объекты, которые могут быть преобразованы в строку с помощью str(). Это могут быть числа, списки и другие объекты.
#
# 4. **Метод format() использует фигурные скобки {} как заполнители.**
#    - **Правда.** В методе format() фигурные скобки {} используются как плейсхолдеры для вставки значений.
#
# 5. **Если в методе format() используются именованные аргументы, на их значения можно ссылаться, используя имя аргумента.**
#    - **Правда.** При использовании именованных аргументов в format() можно ссылаться на их значения по имени.
#
# 6. **Порядок объектов в форматируемой строке изменить нельзя.**
#    - **Ложь.** Порядок объектов в строке можно менять, изменяя порядок фигурных скобок или передавая значения в метод format() в нужном порядке.
#
# 7. **Функция str() используется для строк, а int() — для чисел.**
#    - **Правда.** Функция str() используется для преобразования объектов в строку, а функция int() — для преобразования объектов в целые числа.
#
# 8. **Аргументы 'r' и 'r+' функции open() выполняют одну и ту же функцию.**
#    - **Ложь.** Аргумент 'r' открывает файл только для чтения, а 'r+' открывает файл для чтения и записи.
#
# 9. **В Python мы можем открывать только существующие файлы, а создавать новые файлы нельзя.**
#    - **Ложь.** В Python можно открывать как существующие файлы, так и создавать новые файлы, используя режимы 'w', 'a' и другие.
#
# 10. **В Python можно читать только текстовые файлы.**
#     - **Ложь.** В Python можно читать как текстовые, так и бинарные файлы (например, с использованием режима 'rb').
